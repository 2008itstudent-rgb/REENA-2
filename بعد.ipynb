# %%
import pandas as pd
import gradio as gr

# ============================================
# تحميل البيانات
# ============================================
print("📂 جاري تحميل البيانات...")
try:
    df = pd.read_csv('/content/dataset.csv')
    print(f"✅ تم تحميل {len(df)} أغنية بنجاح!")
except Exception as e:
    print(f"❌ فشل تحميل البيانات: {e}")
    exit()

# ============================================
# دوال البحث (نفسها)
# ============================================
def search_songs(query):
    """البحث في الأغاني والفنانين"""
    if not query or query.strip() == "":
        return "📝 اكتب كلمة للبحث..."

    query = query.lower().strip()
    results = []

    # البحث في اسم الأغنية
    songs = df[df['track_name'].str.lower().str.contains(query, na=False)]
    for _, row in songs.head(5).iterrows():
        results.append(f"🎵 {row['track_name']} - {row['artists']}")

    # البحث في اسم الفنان
    artists = df[df['artists'].str.lower().str.contains(query, na=False)]
    for _, row in artists.head(5).iterrows():
        result = f"🎤 {row['track_name']} - {row['artists']}"
        if result not in results:
            results.append(result)

    if results:
        return "\n\n".join(results)
    else:
        return f"😕 لا توجد نتائج لـ '{query}'"

def get_top_songs(n=5):
    """أشهر الأغاني"""
    if 'popularity' in df.columns:
        top = df.nlargest(n, 'popularity')
        results = []
        for _, row in top.iterrows():
            results.append(f"🏆 {row['track_name']} - {row['artists']}\n   شعبية: {row['popularity']}")
        return "\n\n".join(results)
    return "⚠️ لا يوجد عمود popularity"

def get_stats():
    """إحصائيات سريعة"""
    stats = f"""📊 **إحصائيات المكتبة الموسيقية**

• عدد الأغاني: {len(df):,}
• عدد الفنانين: {df['artists'].nunique():,}
"""
    if 'track_genre' in df.columns:
        stats += f"• عدد الأنواع: {df['track_genre'].nunique()}\n"
    if 'popularity' in df.columns:
        stats += f"• متوسط الشعبية: {df['popularity'].mean():.1f}"
    return stats

def get_genres():
    """عرض أنواع الموسيقى"""
    if 'track_genre' in df.columns:
        genres = df['track_genre'].value_counts().head(10)
        result = "🎸 **أشهر 10 أنواع موسيقية:**\n\n"
        for genre, count in genres.items():
            result += f"• {genre}: {count} أغنية\n"
        return result
    return "⚠️ لا يوجد عمود أنواع"

# ============================================
# الواجهة الرسومية
# ============================================
with gr.Blocks(theme=gr.themes.Soft(), title="🎵 بوت الموسيقى") as demo:
    gr.Markdown("""
    # 🎵 **بوت الموسيقى البسيط**
    ### اكتشف الأغاني من قاعدة بيانات Spotify
    """)

    with gr.Row():
        with gr.Column(scale=2):
            search_input = gr.Textbox(
                label="🔍 ابحث عن أغنية أو فنان",
                placeholder="اكتب اسم الأغنية أو الفنان...",
                lines=1
            )
            search_btn = gr.Button("🔎 بحث", variant="primary")

        with gr.Column(scale=1):
            gr.Markdown("### 📌 أوامر سريعة")
            top_btn = gr.Button("🏆 أشهر الأغاني")
            stats_btn = gr.Button("📊 إحصائيات")
            genres_btn = gr.Button("🎸 أنواع الموسيقى")

    output = gr.Textbox(
        label="📝 النتيجة",
        lines=10,
        interactive=False
    )

    # ربط الأزرار بالوظائف
    search_btn.click(
        fn=search_songs,
        inputs=search_input,
        outputs=output
    )

    search_input.submit(
        fn=search_songs,
        inputs=search_input,
        outputs=output
    )

    top_btn.click(
        fn=get_top_songs,
        inputs=[],
        outputs=output
    )

    stats_btn.click(
        fn=get_stats,
        inputs=[],
        outputs=output
    )

    genres_btn.click(
        fn=get_genres,
        inputs=[],
        outputs=output
    )

    gr.Markdown("""
    ---
    ### 💡 **طريقة الاستخدام:**
    • اكتب اسم أغنية واضغط Enter
    • اكتب اسم فنان (مثال: Taylor)
    • استخدم الأزرار السريعة للاستكشاف

    **ملاحظة:** كل النتائج من ملف البيانات فقط!
    """)

# ============================================
# تشغيل الواجهة
# ============================================
if __name__ == "__main__":
    demo.launch(share=True, debug=True)
# Out:
# 📂 جاري تحميل البيانات...
# ✅ تم تحميل 114000 أغنية بنجاح!
# /tmp/ipython-input-431/2826584263.py:79: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(), title="🎵 بوت الموسيقى") as demo:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://73bb51df65eeabdece.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://73bb51df65eeabdece.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
